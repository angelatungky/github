# %% [markdown]
# <a href="https://colab.research.google.com/github/angelatungky/github/blob/main/Copy_of_yolov8_datasetCombine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 23.3 MB/s eta 0:00:00
# ...

# %%
# !pip install supervision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 kB 4.8 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Yolo v8
# Out:
# /content/drive/MyDrive/Yolo v8

# %%
# !ls
# Out:
# Combine  Dataset  data.yaml  New  runs	yolo11n.pt  yolov8n.pt	yolov8s.pt

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="/content/drive/MyDrive/Yolo v8/data.yaml" epochs=100 imgsz=640 batch=32 amp=True
# Out:
# Ultralytics 8.3.9 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image, display

# Display confusion matrix
display(Image(filename='/content/runs/detect/train2/F1_curve.png'))

# %%
from IPython.display import Image, display

# Display confusion matrix
display(Image(filename='/content/runs/detect/train2/confusion_matrix.png'))

# %%
display(Image(filename='/content/runs/detect/train2/PR_curve.png'))

# %%
display(Image(filename='/content/runs/detect/train2/results.png'))

# %%
display(Image(filename='/content/runs/detect/train2/train_batch0.jpg'))

# %%
display(Image(filename='/content/runs/detect/train2/train_batch1.jpg'))

# %%
display(Image(filename='/content/runs/detect/train2/val_batch0_labels.jpg'))

# %%
display(Image(filename='/content/runs/detect/train2/val_batch1_pred.jpg'))

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt source="/content/drive/MyDrive/Mobil1.MOV" save=True
# Out:
# Ultralytics 8.3.7 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 186 layers, 9,828,438 parameters, 0 gradients, 23.3 GFLOPs
#
# video 1/1 (frame 1/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 1 Motor, 38.1ms
# video 1/1 (frame 2/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 1 Motor, 10.1ms
# video 1/1 (frame 3/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 1 Motor, 9.9ms
# video 1/1 (frame 4/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 9.9ms
# video 1/1 (frame 5/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 9.9ms
# video 1/1 (frame 6/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 1 Motor, 9.9ms
# video 1/1 (frame 7/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 9.9ms
# video 1/1 (frame 8/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 9.9ms
# video 1/1 (frame 9/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 11.2ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt source="/content/drive/MyDrive/Motor4.MOV" save=True
# Out:
# Ultralytics 8.3.7 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 186 layers, 9,828,438 parameters, 0 gradients, 23.3 GFLOPs
#
# video 1/1 (frame 1/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 39.3ms
# video 1/1 (frame 2/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 10.0ms
# video 1/1 (frame 3/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 11.9ms
# video 1/1 (frame 4/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 9.9ms
# video 1/1 (frame 5/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 9.9ms
# video 1/1 (frame 6/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 9.9ms
# video 1/1 (frame 7/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 9.9ms
# video 1/1 (frame 8/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 9.9ms
# video 1/1 (frame 9/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 9.9ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt source="/content/drive/MyDrive/Real60FPS.MOV" save=True
# Out:
# Ultralytics 8.3.7 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 186 layers, 9,828,438 parameters, 0 gradients, 23.3 GFLOPs
#
# video 1/1 (frame 1/2618) /content/drive/MyDrive/Real60FPS.MOV: 384x640 8 Mobils, 2 Motors, 98.8ms
# video 1/1 (frame 2/2618) /content/drive/MyDrive/Real60FPS.MOV: 384x640 9 Mobils, 2 Motors, 10.0ms
# video 1/1 (frame 3/2618) /content/drive/MyDrive/Real60FPS.MOV: 384x640 8 Mobils, 2 Motors, 9.9ms
# video 1/1 (frame 4/2618) /content/drive/MyDrive/Real60FPS.MOV: 384x640 9 Mobils, 3 Motors, 9.9ms
# video 1/1 (frame 5/2618) /content/drive/MyDrive/Real60FPS.MOV: 384x640 9 Mobils, 3 Motors, 9.9ms
# video 1/1 (frame 6/2618) /content/drive/MyDrive/Real60FPS.MOV: 384x640 9 Mobils, 4 Motors, 13.1ms
# video 1/1 (frame 7/2618) /content/drive/MyDrive/Real60FPS.MOV: 384x640 9 Mobils, 4 Motors, 10.0ms
# video 1/1 (frame 8/2618) /content/drive/MyDrive/Real60FPS.MOV: 384x640 8 Mobils, 3 Motors, 9.9ms
# ...
