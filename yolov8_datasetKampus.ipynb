# %% [markdown]
# <a href="https://colab.research.google.com/github/angelatungky/github/blob/main/yolov8_datasetKampus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.4/881.4 kB 23.1 MB/s eta 0:00:00
# ...

# %%
# !pip install supervision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 kB 6.6 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Yolo v8
# Out:
# /content/drive/MyDrive/Yolo v8

# %%
# !ls
# Out:
# Combine  Dataset  data.yaml  New  runs	yolov8n.pt  yolov8s.pt

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="/content/drive/MyDrive/Yolo v8/data.yaml" epochs=100 imgsz=640 batch=8 amp=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.3 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image, display

# Display confusion matrix
display(Image(filename='/content/drive/MyDrive/Yolo v8/runs/detect/train5/F1_curve.png'))

# %%
from IPython.display import Image, display

# Display confusion matrix
display(Image(filename='/content/drive/MyDrive/Yolo v8/runs/detect/train5/confusion_matrix.png'))

# %%
display(Image(filename='/content/drive/MyDrive/Yolo v8/runs/detect/train5/PR_curve.png'))

# %%
display(Image(filename='/content/drive/MyDrive/Yolo v8/runs/detect/train5/results.png'))

# %%
display(Image(filename='/content/drive/MyDrive/Yolo v8/runs/detect/train5/train_batch0.jpg'))

# %%
display(Image(filename='/content/drive/MyDrive/Yolo v8/runs/detect/train5/train_batch16560.jpg'))

# %%
display(Image(filename='/content/drive/MyDrive/Yolo v8/runs/detect/train5/train_batch0.jpg'))

# %%
display(Image(filename='/content/drive/MyDrive/Yolo v8/runs/detect/train5/val_batch0_labels.jpg'))

# %%
display(Image(filename='/content/drive/MyDrive/Yolo v8/runs/detect/train5/val_batch1_pred.jpg'))

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt source="/content/drive/MyDrive/Mobil1.MOV" save=True
# Out:
# Ultralytics 8.3.3 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 186 layers, 9,828,438 parameters, 0 gradients, 23.3 GFLOPs
#
# video 1/1 (frame 1/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 40.0ms
# video 1/1 (frame 2/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 10.1ms
# video 1/1 (frame 3/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 10.0ms
# video 1/1 (frame 4/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 10.0ms
# video 1/1 (frame 5/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 10.0ms
# video 1/1 (frame 6/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 10.0ms
# video 1/1 (frame 7/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 10.0ms
# video 1/1 (frame 8/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 10.0ms
# video 1/1 (frame 9/840) /content/drive/MyDrive/Mobil1.MOV: 384x640 1 Mobil, 10.0ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt source="/content/drive/MyDrive/Motor4.MOV" save=True
# Out:
# Ultralytics 8.3.3 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 186 layers, 9,828,438 parameters, 0 gradients, 23.3 GFLOPs
#
# video 1/1 (frame 1/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 46.3ms
# video 1/1 (frame 2/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 11.2ms
# video 1/1 (frame 3/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 11.4ms
# video 1/1 (frame 4/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 10.0ms
# video 1/1 (frame 5/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 10.1ms
# video 1/1 (frame 6/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 10.0ms
# video 1/1 (frame 7/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 10.0ms
# video 1/1 (frame 8/537) /content/drive/MyDrive/Motor4.MOV: 384x640 (no detections), 10.0ms
# ...
